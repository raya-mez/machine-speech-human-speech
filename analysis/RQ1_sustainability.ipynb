# %%
import os
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

os.chdir("../")

# %%
processed_data_path = "data/processed/responses_processed.csv"

# %%
data = pd.read_csv(processed_data_path)

# %%
unsuccessful_editing = data[
    (data["g"] == 5) & (data["c"].isin([7, 18]))
]

no_editing = data[
    ((data["g"] == 1) & (data["c"] == 15)) |
    ((data["g"] == 4) & (data["c"] == 8))  |
    ((data["g"] == 5) & (data["c"] == 13))
]

display(unsuccessful_editing[['age', 'LLM_use', 'LLM_impact', 'writing_style_pre', 'response_time_minutes', 'remarks']])

display(no_editing[['age', 'LLM_use', 'LLM_impact', 'writing_style_pre', 'response_time_minutes', 'remarks']])
# Out:
#       age                        LLM_use  \
# 90   35.0         Several times per week
# 101  53.0  Every day or almost every day
#
#                                             LLM_impact writing_style_pre  \
# 90   LLM chatbots will have more negative than posi...          Somewhat
# 101  I have no opinion on the impact of LLM chatbot...        Not at all
#
#      response_time_minutes remarks
# 90               20.766667     NaN
# 101              37.033333     NaN
#      age                        LLM_use  \
# 14  27.0    2-3 times in the past month
# 70  44.0  Every day or almost every day
# 96  34.0  Every day or almost every day
#
#                                            LLM_impact writing_style_pre  \
# 14  LLM chatbots will have more positive than nega...          Somewhat
# 70  LLM chatbots will have more positive than nega...          Somewhat
# 96    LLM chatbots will be very beneficial to society          Somewhat
#
# ...
